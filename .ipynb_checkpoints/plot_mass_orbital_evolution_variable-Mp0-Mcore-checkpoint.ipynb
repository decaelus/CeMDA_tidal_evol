# %% [markdown]
# This notebook makes the mass and orbital evolution plots for hot Jupiters undergoing Roche-lobe overflow from Jackson et al. (2016) CeMDA.

# %%
# %matplotlib inline

import mesa_reader as ms
import matplotlib.pyplot as plt
import math
import numpy as np
from itertools import cycle
from astropy import units as u
from astropy.units import cds
import glob

Msol_to_MJup = (cds.Mjup.to('kg')/cds.Msun.to('kg'))
# Out:
# 0.00095455231009

# %%
#First we'll plot the HJs all with Mcore = 10 MEarth.
initial_masses = [0.5, 1., 5., 10.]*cds.Mjup

#Have lines cycle through styles rather than colors
linecycler = cycle(["-","--","-.",":"])

lines = []
line_names = []

# %%
fig = plt.figure(figsize=(8,11))
ax1 = fig.add_subplot(211)

ax1.set_xlabel('$t$ (yrs)', fontsize=24)
ax1.set_ylabel('$P$ (days)', color='b', fontsize=24)
ax2 = ax1.twinx()
ax2.set_ylabel('$M_\mathrm{p}$ ($M_\mathrm{Jup}$)', color='r', fontsize=24)

for cur_initial_mass in initial_masses:
    directory = (glob.glob('./MESA/make_planets_initial-RLO_10Mearth/models/*%.1f*_qs5' % cur_initial_mass.value))
    hst = ms.MesaData(file_name=directory[0] + '/binary_history.data')
    
    lines.extend(ax1.semilogx(hst.get('star_age'), hst.get('period_days'),ls=ls,color='b',lw=3))
    ax2.loglog(hst.data('star_age'), hst.get('star_1_mass')*Msol_to_MJup,ls=ls,color='r', lw=3)
    
    ls = next(linecycler)
